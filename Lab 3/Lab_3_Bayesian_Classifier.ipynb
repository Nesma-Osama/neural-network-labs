# %% [markdown]
# # Bayesian Classifier
# In this lab, you will implement and assess the performance of the Bayesian Classifier.
#
# ## Lab Instructions:
# 1. Read the explanation above each requirement very well
# 2. Read the requirement very well before jumping into the code.
# 3. Some requirements have essay questions in them, make sure you do NOT miss them.
# 4. PLEASE Read the hints! They are clear and made to help you complete the requirement as fast as you should

# %%
#### always keep all your imports in the first cell ####
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import csv
import os
import math
import pandas as pd

# %matplotlib qt

# %% [markdown]
# ## Requirement
#
# In this requirement, you will build the Bayesian Classifier and test its performance.
#
# You are provided with a data file **data1.csv** containing list of points and their corresponding classes. The format of the data files is shown in the table below.
#
# | |Class|Feature 1|Feature 1|
# |-|-|-|-|
# |Point#1|1|0.271633|-2.93224|
# |Point#2|1|7.020786|-1.98966|
# |Point#3|1|2.901827|-0.91291|
#
#
# You are also provided with a test data file **test_data.csv**. The file contains test points that are unlabelled (i.e. the class to which they belong is unknown).

# %%
# TODO [1] : Read the file 'data1.csv' into the variable data.
# data contains the training data together with labelled classes.
def read_data(file_name):
    ## HINT 1: How is the data ordered in the file?
    ## HINT 2: Do you need to cast the data you read from the file?
    data = pd.read_csv(file_name,header=None)
    return data

# %%
def read_test_data():

    # TODO [2.A]: Read the file 'test_data.csv' into the variable test_data
    # test_data contains the unlabelled test class.
    ## HINT: Do you need to cast the data you read from the file?

    test_data = read_data("test_data.csv")
    test_data.columns = [f"feature{i}" for i in range(1,test_data.shape[1]+1)]

    # TODO [2.B]: Read the file 'test_data_true.csv' into the variable test_data_true
    # test_data_true contains the actual classes of the test instances, which you will compare
    # against your predicted classes.
    ## HINT: Do you need to cast the data you read from the file?

    test_data_true =read_data("test_data_true.csv")
    test_data_true.columns = ["Class"]
    test_data_true['Class']=test_data_true['Class'].astype(int)
    return test_data, test_data_true

# %% [markdown]
# ### Machine Learning Terminlology
# Machine learning problems use common termonology (names and notiations) to refer to certain things. It is useful to use this termonology throughout your code to make it readable.
#
# | | |
# |:-|:--- |
# |$M$:|A scalar; represents the number of training points in the training set.|
# |$K$:|A scalar; represents the number of test points in the test set.|
# |$N$:|A scalar; represents the number of features of training set/test set (dimensionality of data).|
# |$X$:|A numpy array of shape $(M \times N)$ containing the training data **without** its labels, where $M$ is the number of training points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset.|
# |$X_{test}$:| A numpy array of shape $(K \times N)$ containing the test data, where $K$ is the number of test points and $N$ is the number of features in the dataset (or dimensionality of features). <br/> Each element in $X_{test}$ is a tuple $(X_1, X_2, \dots, X_N)$ where $N$ is the number of features in the dataset. <br/> The number of columns in $X_{test}$ is equal to the number of columns in $X$ (because they have the same number of features). However, the number of rows in $X_{test}$ is different to the number of rows in $X$.|
# |**$Y$:| A numpy array of shape $(M \times 1)$ containing the labels of the training data. Each row in $Y$ corresponds to the label of the training point in $X$.<br/> For example, $Y[j]$ corresponds to the label of the training point $X[j]$ where $0<=j<M$.|

# %%
# TODO [3]: Fill the values of M, K, N, X, XTest, and Y respectively.
# Do not fill them manually (i.e. do not set N = 3). They should be generic for any input file.
training_data = read_data('data1.csv')
columns=([f"feature{i}" for i in range(1,training_data.shape[1])])
columns.insert(0,"Class")
training_data.columns = columns
training_data['Class']=training_data['Class'].astype(int)
training_features=training_data.drop(columns=["Class"])
#############################################################
test_data, test_data_true = read_test_data()
numClasses = 3
M = training_data.shape[0]
N =  test_data.shape[1]
K = test_data.shape[0]
########################################
X =np.array([tuple(training_features.iloc[i]) for i in range (0,len(training_data)) ])
X_Test = np.array([tuple(test_data.iloc[i]) for i in range (0,len(test_data)) ])
Y = np.array(training_data['Class']).reshape(M,1)

# %%
test_data_true
# Out:
#      Class
# 0        3
# 1        1
# 2        2
# 3        3
# 4        3
# ..     ...
# 445      3
# 446      3
# 447      2
# 448      3
# 449      3
#
# [450 rows x 1 columns]

# %%
# TODO [4]: Draw a scatter plot for traning data, where each class is coloured by the colour corresponding
#           to its index in the colors array.
# Class 1 should be coloured in red, Class 2 should be coloured in green, and Class 3 should be coloured in blue.
# Hint: We have done a similar plot in the previous lab. What operation do we need to select training data
#       belonging to a certain class?

colors = ['r', 'g', 'b', 'c', 'y']
colors_list=[colors[i[0]-1]for i in Y]
plt.scatter(X[:,0],X[:,1],c=colors_list)
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('Training Data')
plt.show()

# %%
## What do you notice about the plot? (Write everything you can think of)
'''
    Your Answer:
    they are interleaved
    there will be more than one decision boundary
    there will be misclassification
'''
# Out:
# '\n    Your Answer:\n    they are interleaved\n    there will be more than one decision boundary\n    there will be misclassification\n'

# %% [markdown]
# ### Bayesian Classifier
# The Bayesian Classifier calculates the probability of the test point belonging to each class, then the class with highest probability is assigned to the test point.
#
# Classification of $x_{test}$ = $argmax_{i} P\big(C_i|x_{test}\big)$ = $argmax_{i} P(x|C_i) * P(C_i)$
#
# * $P(C_i|x_{test})$: Posterior probability
# * $P(x|C_i)$: Class-conditional probability (or distribution)
# * $P(C_i)$: Class apriori probability
#
# **Note that** $P(C_i|x_{test}) \neq P(x_{test}|C_i) * P(C_i)$. Instead,  $P(C_i|x_{test}) = \frac{P(x_{test}|C_i) * P(C_i)}{P(x_{test})}$. However, when we compare multiple classes, the denominator $P(x_{test})$ is independent of the class $i$ and can be regarded as normalizing factor.
#
# **We start by** computing statistical parameters about each class from the data.
#
# For each class, we are interested in **three** parameters that will be used for calculating the Gaussian class-conditional distribution and the posterior probability.
#
# These parameters are:
#
# |||
# |:-|:-|
# |**Class Apriori Probability: ($P_C$)**| A scalar; the probability of class occurence (how frequent this class appears in the training data)|
# |**Class Mean: ($\mu$)**| A vector of shape $(N \times 1)$, it is the expected value (mean) calculated from the training points of each class.|
# |**Class Covariance Matrix: ($\Sigma$)**| A square symmetric matrix of shape $(N \times N)$ representing the covariances between all the feature calculated from the training points of the class. <br/> For example: Matrix element $\sigma^2_{12}$ is the covariance between the 1st and the 2nd features|

# %%
pClasses = [] # A list of size (numClasses, 1) containing the a priori probabilities of each class in the training set.

estimate_means = [] # A numpy array of size (numClasses, N) containing the mean points of each class in the training set.
                    # HINT: USE NP.MEAN

estimate_covariances = [] # A numpy array of size (numClasses, N, N) containing the covariance matrices of each class in the training set.
                          # HINT: USE NP.COV (Pay attenention for what it takes as an argument)

for classIndex in range(numClasses):
    # TODO [5]: Estimate the parameters of the Gaussian distributions of the given classes.
    # Fill pClasses, estimate_means, and estimate_covariances in this part
    # Your code should be vectorized WITHOUT USING A SINGLE FOR LOOP.
    class_data=X[training_data['Class']==classIndex+1]
    pClasses.append(np.float32(len(class_data) / len(training_data)))
    estimate_means.append(np.mean(class_data,axis=0))
    cov_matrix = np.cov(class_data, rowvar=False)
    estimate_covariances.append(cov_matrix)
estimate_means = np.array(estimate_means)
estimate_covariances = np.array(estimate_covariances)

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
assert len(pClasses) == numClasses,\
        'Incorrect class apriori probability list, it should be of length {}'.format(len(pClasses))
#assert np.sum(pClasses) == 1
assert np.sum(pClasses)==1,\
        'Sum of apriori probabilities should be 1, found {}'.format(np.sum(pClasses))
assert estimate_means.shape == (numClasses, N),\
        'Incorrect estimated means, it should be of shape {}'.format((numClasses, N))
assert estimate_covariances.shape == (numClasses, N, N),\
        'Incorrect estimate covariance matrices, it should be of shape {}'.format((numClasses, N, N))

# %% [markdown]
# **The second step** in the classifier is to calculate the class-conditional density using the Gaussian destribution:
#
# $P(x|C_i) = \mathcal{N}(x; \mu_i, \Sigma_i) = \frac{1}{(2\pi)^{\frac{N}{2}}|\Sigma_i|^{\frac{1}{2}}} exp\big(\frac{-1}{2}(x-\mu_i)^T\Sigma^{-1}_{i}(x-\mu_i)\big)$

# %%
# TODO 6: Implement the multivariate normal gaussian distribution with parameters mu and sigma, and return the
#  value in prob.
def multivariate_normal_gaussian(X, mu, sigma):
    N = len(mu)  # Number of features

    # Reshape inputs to be 1D arrays (flattened)
    X = X.flatten()
    mu = mu.flatten()

    prob=(1/((2*np.pi)**(N/2)*np.linalg.det(sigma)**(1/2)))*np.exp(-0.5*(X-mu).T@np.linalg.inv(sigma)@(X-mu))
    return np.array([[prob]])

# %%
### Test your implementation ###
### DO NOT CHANGE THIS CODE ###
np.random.seed(90)
assertion_x = np.random.rand(3).reshape(-1,1)
assertion_mu = np.random.rand(3).reshape(-1,1)
assertion_sigma = np.random.rand(9).reshape(3,3)
assertion_probability = multivariate_normal_gaussian(assertion_x, assertion_mu, assertion_sigma)[0][0]
assertion_probability = round(assertion_probability, 1)
assert assertion_probability == 7.8,\
    'Incorrect Gaussian Probability calculated'

# %% [markdown]
# **The final step** is to go for each test point, calculate its posterior probability against each class, then classify it to the class with the highest posterior probability.

# %%
# TODO [7]: Apply the Bayesian Classifier to predict the classes of the test points.
predicted_classes = [] # predicted_classes: A numpy array of size (K, 1) where K is the number of points in the test set. Every element in this array
                       # contains the predicted class of Bayes classifier for this test point.

for i in range(X_Test.shape[0]):
    print("For test point:", X_Test[i])
    classProbabilities = np.zeros(numClasses)
    # TODO [7.A]: Compute the probability that the test point X_Test[i] belongs to each class in numClasses.
    #  Fill the array classProbabilities accordingly.
    for j in range(0,numClasses):
      classProbabilities[j]=multivariate_normal_gaussian(X_Test[i],estimate_means[j],estimate_covariances[j])[0][0]*pClasses[j]

    # TODO [7.B]: Find the prediction of the test point X_Test[i] and append it to the predicted_classes array.
    predicted_classes.append(np.argmax(classProbabilities)+1)

    print('Class Probabilities: ', classProbabilities)  # the first class is the left most in the scatter plot
    print("Predicted class is :", predicted_classes[i])
    print("******************************************************************************")
# Out:
# For test point: [10.70141426  3.87253627]
# Class Probabilities:  [2.65667369e-12 2.14599818e-17 2.49128525e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.81831787 -5.00977814]
# Class Probabilities:  [1.54057602e-02 1.59733840e-10 1.94606990e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.57071936  9.96036181]
# Class Probabilities:  [7.93462233e-20 1.36556780e-03 5.38717656e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 4.94309043 -0.01539406]
# Class Probabilities:  [1.95768742e-06 1.94246412e-08 5.69470414e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.26082551 -0.61349358]
# Class Probabilities:  [6.24062348e-06 4.98423494e-08 4.72790297e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.98901139 16.86268221]
# Class Probabilities:  [4.48752932e-36 3.09285825e-04 1.66266006e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.2796485  -3.38655342]
# Class Probabilities:  [2.21653326e-03 1.16512387e-07 8.33834051e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.60503344 -0.24206319]
# Class Probabilities:  [8.51743057e-05 1.94834880e-06 2.24458317e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.84312621 12.42130394]
# Class Probabilities:  [7.22909570e-20 5.21791895e-03 1.70142222e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.52253054 10.13668928]
# Class Probabilities:  [3.13513925e-25 1.40321649e-06 7.46137148e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.59472055 -4.37938379]
# Class Probabilities:  [2.85106525e-09 3.52756728e-12 1.15602245e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98596817 -0.73837508]
# Class Probabilities:  [7.99411914e-04 1.19354044e-06 4.43428946e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.23908496 13.21358765]
# Class Probabilities:  [7.41762393e-26 3.31840121e-03 3.77648963e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -6.7789975 -11.0163502]
# Class Probabilities:  [1.08876573e-03 1.60723618e-20 2.07172914e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.59545273 -0.41955489]
# Class Probabilities:  [5.73709430e-04 1.06972381e-05 4.58273650e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.36129364 -5.42102971]
# Class Probabilities:  [4.93589609e-15 1.81083200e-17 2.37754211e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.52848225 -7.42893531]
# Class Probabilities:  [1.95401639e-03 5.80993838e-12 1.27194651e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.56086046 -9.03278997]
# Class Probabilities:  [2.59963484e-03 2.66267161e-15 4.98120004e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.02188067 -0.93735269]
# Class Probabilities:  [6.30158096e-09 6.99963184e-12 5.27535837e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.1509862  1.43750612]
# Class Probabilities:  [9.02780229e-11 1.11683139e-14 2.17487213e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.71007022 10.6797775 ]
# Class Probabilities:  [6.14531732e-19 9.85768330e-03 2.90112514e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.76302456 -5.55297678]
# Class Probabilities:  [1.71586845e-02 6.63592452e-12 2.25174619e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.89883417 -5.39496672]
# Class Probabilities:  [1.65351138e-02 6.68116274e-12 1.99600309e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.03379007 2.71590677]
# Class Probabilities:  [3.25890817e-09 6.33380440e-12 2.25024363e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.89215726 -2.59460822]
# Class Probabilities:  [2.35266731e-03 1.54638574e-09 1.07116644e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.11834647  4.91066223]
# Class Probabilities:  [1.04649640e-10 8.44017467e-05 3.54716767e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.45717699 -2.43934454]
# Class Probabilities:  [5.07994010e-09 6.00780292e-12 3.64390036e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.56547098 4.9207542 ]
# Class Probabilities:  [2.07859383e-07 1.10058954e-03 8.50552214e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.26265631 6.5794146 ]
# Class Probabilities:  [2.26255537e-09 3.47120371e-03 1.01432184e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.70832433 -3.11174424]
# Class Probabilities:  [3.09054003e-05 2.15868875e-08 1.14306192e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -9.10836917 -11.76552446]
# Class Probabilities:  [8.17205978e-04 1.11871772e-25 1.87039914e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.81726658 -5.3687788 ]
# Class Probabilities:  [1.66047051e-02 8.62791992e-12 2.38357001e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.30975347  9.75343174]
# Class Probabilities:  [1.72678275e-15 1.45116255e-02 1.24168859e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-7.58893623 -3.93631034]
# Class Probabilities:  [6.68507033e-04 2.69710038e-14 1.66023115e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-11.3843618 -12.1472865]
# Class Probabilities:  [2.36181992e-04 1.81519644e-31 1.48001338e-19]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.15303864 -5.99521012]
# Class Probabilities:  [9.52218485e-12 2.65861630e-14 2.49472681e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [0.88072334 9.72115039]
# Class Probabilities:  [2.03278374e-14 8.73359730e-03 5.14055326e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.3263618 8.7977202]
# Class Probabilities:  [1.52281937e-12 5.76223131e-03 4.07909756e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.70501109 11.56174259]
# Class Probabilities:  [1.23831450e-25 1.45196245e-04 2.03066478e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.12643357 -4.83616859]
# Class Probabilities:  [1.28546333e-02 7.52713345e-10 7.01438044e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.05674244 12.57155861]
# Class Probabilities:  [1.42657845e-17 2.98293264e-05 1.47833733e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ -4.30106198 -10.6042502 ]
# Class Probabilities:  [1.96590949e-04 6.64738623e-17 5.74518276e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 5.11776496 -0.99143917]
# Class Probabilities:  [8.67064347e-07 3.31293297e-09 5.48755980e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 6.05493358 -5.87189841]
# Class Probabilities:  [1.91155289e-11 4.69464775e-14 2.87311203e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.74275953 -3.97527522]
# Class Probabilities:  [1.18595008e-06 7.60486090e-10 1.09158157e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.02170247 -5.57244813]
# Class Probabilities:  [1.60749250e-02 3.28317700e-11 8.50671968e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.27810154 -3.99998321]
# Class Probabilities:  [7.21774982e-03 4.33520035e-11 2.60633335e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.80988364 3.43699512]
# Class Probabilities:  [1.87857685e-07 4.98276963e-08 2.01393147e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.6311676  1.76165524]
# Class Probabilities:  [5.20542156e-10 1.83337235e-13 2.59042821e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.73761305 -6.16978647]
# Class Probabilities:  [1.72079005e-02 1.82566897e-12 1.32335097e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.28411495 -2.28452888]
# Class Probabilities:  [1.67178435e-21 2.46223918e-27 2.69611643e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.47775397 -0.10213091]
# Class Probabilities:  [4.27672829e-04 5.64424884e-06 9.64961022e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.42758688 -7.1513932 ]
# Class Probabilities:  [1.15591074e-02 3.93607963e-13 8.04615873e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.71805696 -8.49355483]
# Class Probabilities:  [1.41749268e-04 1.02901558e-12 9.19853554e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.07056432 13.27106731]
# Class Probabilities:  [3.48135614e-29 2.95452886e-04 1.19575623e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.82594718 -9.52426172]
# Class Probabilities:  [1.53492742e-04 1.97327371e-14 4.00060697e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.2893587   1.35319816]
# Class Probabilities:  [1.93246607e-12 2.76184825e-17 1.04650734e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.13419282  9.00152907]
# Class Probabilities:  [7.59348221e-15 1.28409787e-02 1.62680527e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.29226867  7.97517886]
# Class Probabilities:  [2.71580582e-12 1.17677605e-02 2.65046386e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 9.46997908 -1.99299457]
# Class Probabilities:  [2.39959005e-13 3.36845612e-17 1.38599121e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.05416915 -2.47425901]
# Class Probabilities:  [3.74946801e-03 4.68398868e-07 5.06444907e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 2.21553241 12.53863186]
# Class Probabilities:  [8.06489490e-19 1.08467996e-03 4.74822475e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85953786 -0.76518719]
# Class Probabilities:  [2.06773914e-11 3.60108207e-15 2.78656755e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.11560394 -2.51521659]
# Class Probabilities:  [2.59078369e-06 4.17946067e-09 2.79471369e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.88633577 -7.73994173]
# Class Probabilities:  [1.32138474e-02 2.03335124e-15 2.33177947e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.79933965  5.31322455]
# Class Probabilities:  [2.53450136e-09 2.35586970e-03 1.13693436e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.34271378 16.23529621]
# Class Probabilities:  [1.01454421e-28 2.78267118e-04 9.88574258e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.55913997 10.48707791]
# Class Probabilities:  [2.63166635e-15 4.43196656e-03 2.29496414e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.86122888  7.15903434]
# Class Probabilities:  [3.15434229e-12 5.64340143e-03 1.04219327e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.38794864  4.18558645]
# Class Probabilities:  [5.87505761e-09 1.73911091e-04 2.67347081e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.52727338 -7.21208436]
# Class Probabilities:  [1.37168702e-03 4.09520471e-21 7.19072052e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.98956144 -7.5666012 ]
# Class Probabilities:  [1.16718314e-02 3.77404765e-14 1.71546424e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.75405923 -5.30192282]
# Class Probabilities:  [6.95117986e-04 1.25640423e-17 3.55310340e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.94621632 -6.88516599]
# Class Probabilities:  [1.04371706e-02 2.04402041e-12 2.55802048e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31994442 -2.63044722]
# Class Probabilities:  [1.69856999e-03 4.89633096e-10 4.53858956e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-9.36297948 -8.56822792]
# Class Probabilities:  [2.89374912e-03 2.92800371e-22 2.03700854e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.81585174 -3.0905699 ]
# Class Probabilities:  [6.88546689e-03 6.52627001e-09 6.39617044e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.48384894 -2.13782697]
# Class Probabilities:  [2.43490258e-17 3.87480835e-22 2.42544592e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [7.38337554 4.66707989]
# Class Probabilities:  [5.90912032e-09 3.86405418e-10 7.24794219e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.19811716 -3.20869437]
# Class Probabilities:  [8.33437089e-03 1.52642316e-08 1.71444213e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.73664819 -5.64026754]
# Class Probabilities:  [1.73201502e-02 5.85707812e-12 2.18927062e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.16135146 8.11909452]
# Class Probabilities:  [1.39449790e-10 3.09076202e-06 1.16946813e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.93192373 -7.90304636]
# Class Probabilities:  [9.30691956e-03 1.91571577e-14 1.24385355e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.44663034 -1.10812617]
# Class Probabilities:  [5.29369464e-11 1.53334793e-14 3.20144558e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.41266737  -6.02755366]
# Class Probabilities:  [1.04013103e-04 7.28480758e-22 1.99048909e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-10.55452885  -6.98597699]
# Class Probabilities:  [2.43229223e-04 3.53443388e-23 5.08979735e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.16708742 -4.41114641]
# Class Probabilities:  [1.31152575e-03 1.73945705e-08 4.93438369e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.83499316 3.0513492 ]
# Class Probabilities:  [4.11740811e-08 1.05374229e-09 2.48195931e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.3218284   8.03062152]
# Class Probabilities:  [2.08715389e-12 1.19554120e-02 2.34516140e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.67262506 -3.63638033]
# Class Probabilities:  [9.59811406e-03 1.47628777e-08 3.15312001e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.23839346 15.50904654]
# Class Probabilities:  [6.66221618e-27 5.80140276e-04 7.70463735e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.85415463 -9.49083878]
# Class Probabilities:  [3.74127363e-06 1.39220879e-13 5.58979508e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.57934474 14.05416562]
# Class Probabilities:  [1.45103088e-25 4.14231340e-03 5.08444304e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.08121918 9.02118593]
# Class Probabilities:  [4.60310544e-13 7.31367394e-03 2.20074176e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.54545494 13.38470402]
# Class Probabilities:  [1.52996136e-28 6.66099864e-04 2.45389284e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.25685021 12.98458764]
# Class Probabilities:  [8.23191241e-22 5.87566759e-03 2.26792418e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.49117921 -2.09111202]
# Class Probabilities:  [8.81985105e-12 3.09762033e-15 2.31677839e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [9.6377611  2.59220877]
# Class Probabilities:  [4.14289164e-11 2.76739027e-15 1.09511925e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.99632131 -0.81831291]
# Class Probabilities:  [3.57531034e-10 1.63139393e-13 4.07559795e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.8066989  12.60496257]
# Class Probabilities:  [1.77028787e-18 4.04530483e-04 6.41031282e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.14054117 13.99755821]
# Class Probabilities:  [8.29453919e-25 4.00478071e-03 1.04918221e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.0622924  -4.14345298]
# Class Probabilities:  [1.18451134e-02 3.27311705e-09 1.26744559e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.73588097 -8.59503648]
# Class Probabilities:  [7.97952484e-03 3.68934494e-16 9.99969614e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.87691909 -8.51465367]
# Class Probabilities:  [5.59643692e-03 4.72737097e-15 5.97595138e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 8.30461631 -2.42881748]
# Class Probabilities:  [9.38363495e-12 4.27091886e-15 2.18519504e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.92551153  9.38904848]
# Class Probabilities:  [1.88205970e-16 8.79591715e-03 2.55603956e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-8.06681967 -9.76445434]
# Class Probabilities:  [4.58042481e-03 3.98146949e-21 9.32525427e-14]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.24410989 -8.18831047]
# Class Probabilities:  [6.57602010e-03 1.25859909e-19 6.13090315e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.37602904 -5.99069434]
# Class Probabilities:  [1.70089597e-02 5.28923284e-13 4.59476150e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.22386765 -4.85135398]
# Class Probabilities:  [1.23773672e-06 3.90395376e-10 4.52107821e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.55406083 -2.89224039]
# Class Probabilities:  [2.63146422e-04 1.25919291e-07 5.91537570e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.69049165 13.4044702 ]
# Class Probabilities:  [2.95306568e-20 3.34545828e-04 8.41277290e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.53571156 10.66187251]
# Class Probabilities:  [5.60674376e-20 5.06738556e-03 8.10366423e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.96782552 -4.31305255]
# Class Probabilities:  [4.04246772e-07 2.56097113e-10 9.23284330e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.00081432  8.87275799]
# Class Probabilities:  [1.67515347e-15 7.88095541e-03 5.69502637e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.35696677 -3.77423836]
# Class Probabilities:  [5.68497554e-03 5.42958067e-11 2.53165531e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.48811048 -3.16156655]
# Class Probabilities:  [4.56384364e-11 4.08006828e-14 2.02979428e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.06573364 -13.36721214]
# Class Probabilities:  [7.53962464e-06 1.26531054e-22 7.00864260e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.1851141 2.6171304]
# Class Probabilities:  [8.14105406e-07 1.67541195e-07 2.98411567e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.27828524 1.31354615]
# Class Probabilities:  [1.10560109e-09 5.83850837e-13 3.39686685e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.79242965 1.64031539]
# Class Probabilities:  [9.26493865e-06 2.10737230e-06 2.98024074e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.138666   6.8602675]
# Class Probabilities:  [1.89448440e-10 8.12960602e-03 1.59428455e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 5.78244942 -9.12198008]
# Class Probabilities:  [2.29088881e-15 6.96110505e-17 3.52906689e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.60435329 -5.38072375]
# Class Probabilities:  [1.82459301e-07 6.81871382e-11 3.28809540e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.85525938 -6.34543458]
# Class Probabilities:  [1.27879474e-02 8.38327008e-12 5.37571619e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [13.08621387  1.9348786 ]
# Class Probabilities:  [6.86376425e-17 1.31615912e-24 5.32648825e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.97701781 -8.26247269]
# Class Probabilities:  [3.61946367e-03 6.90964445e-14 4.26738867e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.3366769  1.22185752]
# Class Probabilities:  [1.29748317e-04 9.39161428e-05 2.76506237e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-9.28532526 -9.4355402 ]
# Class Probabilities:  [3.06955818e-03 4.14727412e-23 7.04757922e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.66429005 11.01189494]
# Class Probabilities:  [3.26437728e-16 3.60441561e-03 8.69323040e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.08966182 -1.69228564]
# Class Probabilities:  [2.45837097e-03 2.38064855e-07 3.38446722e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.33789356 -2.66619436]
# Class Probabilities:  [5.23541689e-09 6.31071576e-12 3.32398164e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.56901228  5.51033591]
# Class Probabilities:  [7.94607609e-09 4.31603221e-03 4.89059341e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 2.99286099 -4.68078563]
# Class Probabilities:  [2.84041612e-06 8.01002890e-10 4.67328146e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.80021733 11.42437424]
# Class Probabilities:  [9.51190458e-21 8.27063117e-03 5.18953594e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 1.16929961 -4.74585978]
# Class Probabilities:  [1.26842183e-04 5.78918383e-09 1.34516942e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.15245262 14.77479741]
# Class Probabilities:  [1.99538595e-26 2.19621695e-03 1.82856984e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.57247905  -6.73922446]
# Class Probabilities:  [2.60970505e-05 1.96025524e-25 3.08351956e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.60476346  4.55773513]
# Class Probabilities:  [9.05061863e-12 2.08984156e-06 2.51846189e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 7.91493717 -4.93203896]
# Class Probabilities:  [1.37003210e-13 3.13128820e-16 4.64153297e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.40280867 -4.97280708]
# Class Probabilities:  [1.25337118e-02 4.37925800e-12 1.04766219e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [2.04297042 2.03014309]
# Class Probabilities:  [2.90520913e-05 5.95100574e-05 9.35060677e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ -6.21122011 -10.70086807]
# Class Probabilities:  [1.16055015e-03 2.72947312e-19 1.24362878e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.53064612 -8.83892725]
# Class Probabilities:  [6.04943330e-03 3.55431107e-16 1.05893793e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.30022088 11.20197432]
# Class Probabilities:  [1.75823185e-15 2.58282357e-04 2.02894781e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.52678262 11.00539841]
# Class Probabilities:  [3.54009938e-17 9.64922360e-03 2.79120671e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [6.2375991  2.80421505]
# Class Probabilities:  [1.36281018e-07 7.24159590e-09 2.95257836e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.1883182  -1.89030168]
# Class Probabilities:  [4.09664180e-05 5.03398180e-12 9.19628036e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.60122702 15.01466265]
# Class Probabilities:  [3.54712893e-28 2.21259962e-03 3.51254824e-14]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.34641109 -4.86072033]
# Class Probabilities:  [3.91750190e-03 4.94832988e-09 8.83709751e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 6.63822042 -5.45296469]
# Class Probabilities:  [6.03133018e-12 1.54169684e-14 4.10065540e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [6.54807184 1.19913258]
# Class Probabilities:  [8.61501120e-08 5.25993319e-10 5.31205086e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [11.7595198   0.33353443]
# Class Probabilities:  [1.49437421e-15 1.69358742e-21 3.11246804e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.04384705  3.3153199 ]
# Class Probabilities:  [1.63552386e-11 5.69709306e-16 5.78023876e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.72322077 2.89573292]
# Class Probabilities:  [3.51937807e-06 8.15314498e-06 1.63550412e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.23412033 10.5086633 ]
# Class Probabilities:  [3.82776128e-22 4.26857531e-04 5.07665310e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [2.75812898 9.80988701]
# Class Probabilities:  [2.10400419e-13 8.77542470e-04 2.21523794e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [5.71709878 0.05250004]
# Class Probabilities:  [3.88528305e-07 2.23256646e-09 6.23703786e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.4383003  14.46253234]
# Class Probabilities:  [1.94242573e-33 8.08690641e-05 2.36867237e-16]
# Predicted class is : 2
# ******************************************************************************
# For test point: [10.31980548  5.65793048]
# Class Probabilities:  [6.53273137e-12 4.73874940e-16 7.50448380e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.37524372  -7.74958537]
# Class Probabilities:  [6.15613634e-04 1.39963555e-23 3.55299102e-15]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.60020077 -5.42453553]
# Class Probabilities:  [1.69751353e-02 1.28312545e-11 3.41456842e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.20850522 -0.73094364]
# Class Probabilities:  [3.77193598e-05 3.74177772e-07 3.07100717e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.67511969 -0.45766944]
# Class Probabilities:  [5.99089195e-11 1.26600717e-14 3.18618452e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.84241029 -2.07200837]
# Class Probabilities:  [3.83779257e-03 1.82737694e-07 4.60607052e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [5.02815393 0.12504483]
# Class Probabilities:  [1.71035117e-06 1.83493627e-08 5.75557351e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.63527967 10.82193815]
# Class Probabilities:  [7.11998114e-16 3.86455204e-03 1.25293427e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.69546404 1.63793279]
# Class Probabilities:  [2.72878666e-06 2.48567544e-07 4.03485023e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-4.20495861 -8.54182529]
# Class Probabilities:  [3.29787142e-03 2.11363836e-14 1.93917579e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.85664823  8.27107861]
# Class Probabilities:  [1.78031933e-19 7.44871788e-06 1.07085953e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.43266395 -7.3131535 ]
# Class Probabilities:  [1.46025885e-02 2.13704364e-14 9.88711972e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.43743782 10.57358038]
# Class Probabilities:  [2.47270916e-14 2.22922204e-04 7.92812593e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51691079 1.90895905]
# Class Probabilities:  [3.12738050e-06 5.16556335e-07 3.49280637e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.95393725 -2.06290005]
# Class Probabilities:  [3.88441278e-05 8.16947180e-08 2.03950980e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.17022706 -4.71914956]
# Class Probabilities:  [8.04241373e-03 3.29674530e-09 3.24852437e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [6.87943361 0.56763302]
# Class Probabilities:  [3.09445271e-08 7.83639666e-11 5.67104109e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.90155375 -2.49446135]
# Class Probabilities:  [8.28533767e-13 2.52940703e-16 1.57149898e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.75309704 10.13350214]
# Class Probabilities:  [2.82204035e-15 9.38313420e-03 2.06153657e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-6.83046209 -9.95463151]
# Class Probabilities:  [3.68858131e-03 2.76801532e-19 1.20296709e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.48084666 2.21690041]
# Class Probabilities:  [1.17515238e-08 4.16253912e-11 3.30256215e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.51484158 16.05856446]
# Class Probabilities:  [1.47744723e-36 1.26592172e-04 1.38472166e-17]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.29796106 -1.51960377]
# Class Probabilities:  [2.55799092e-03 8.59738276e-07 1.19502285e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.04675075 14.39325425]
# Class Probabilities:  [2.80627338e-24 1.57901192e-03 1.44686544e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.33223697 -7.63241344]
# Class Probabilities:  [3.74324975e-03 1.08369965e-12 2.87594163e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.38944943 -9.23325113]
# Class Probabilities:  [1.74350241e-03 2.33165454e-15 4.97074353e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.74176393 -5.02512921]
# Class Probabilities:  [1.54083006e-02 2.13030267e-11 3.64044533e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.41004634 -5.5997003 ]
# Class Probabilities:  [4.72479944e-03 1.67497253e-15 7.84334745e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.09797276 -7.51282903]
# Class Probabilities:  [6.66456776e-03 1.26877937e-18 2.06837434e-12]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 1.65055    14.73266536]
# Class Probabilities:  [2.10233279e-24 6.65526863e-04 1.04925984e-12]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.15219027 3.63873026]
# Class Probabilities:  [2.77343123e-06 6.36133140e-04 1.75334222e-04]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.25543293  9.24132191]
# Class Probabilities:  [1.98383373e-15 1.25902256e-02 8.98402534e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.3701864  10.61688349]
# Class Probabilities:  [1.19045217e-19 5.98517276e-03 1.16796949e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-11.26329666  -7.92344489]
# Class Probabilities:  [1.70947555e-04 6.35565080e-26 2.08120748e-16]
# Predicted class is : 1
# ******************************************************************************
# For test point: [1.37598504 5.76529642]
# Class Probabilities:  [2.37662735e-08 2.14944749e-03 2.98257136e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.88140712 -3.02402962]
# Class Probabilities:  [6.40177332e-03 6.49486015e-09 5.87202324e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-3.66886091 -1.94857083]
# Class Probabilities:  [2.50112074e-03 6.09575774e-08 1.21408932e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.21817753 10.22511294]
# Class Probabilities:  [6.50255117e-16 1.24195647e-02 9.52157790e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.01734447 -3.01633766]
# Class Probabilities:  [1.80200737e-05 1.55727703e-08 1.41456153e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.45242039 2.18725534]
# Class Probabilities:  [1.94002523e-05 4.03147716e-05 1.16243869e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81338366 -3.04810313]
# Class Probabilities:  [2.64600866e-05 2.04907789e-08 1.25131406e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.35226244  7.94145336]
# Class Probabilities:  [4.08259296e-13 9.72111463e-03 6.86844588e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.32479122 -9.12757714]
# Class Probabilities:  [1.35614540e-04 1.08953437e-13 1.55592726e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.99032273 -0.46466519]
# Class Probabilities:  [9.09212799e-15 6.89958462e-20 6.28472312e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.52557256 -5.00051738]
# Class Probabilities:  [2.51159236e-03 3.92118023e-15 9.65818694e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31739532 -7.08917772]
# Class Probabilities:  [1.54196790e-02 5.00113421e-14 1.61626318e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-2.87484239  6.36256125]
# Class Probabilities:  [7.72653765e-12 1.46454173e-03 6.08403118e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70055404 17.81508726]
# Class Probabilities:  [1.34099536e-38 1.38097824e-04 1.16559377e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.83913631 -3.92362328]
# Class Probabilities:  [1.14205140e-02 1.32990270e-09 3.98931871e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.31785661 -8.22012729]
# Class Probabilities:  [8.87303791e-03 3.14756253e-15 3.87796940e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 4.41220473 -0.78866093]
# Class Probabilities:  [4.36734950e-06 2.74063553e-08 4.85836625e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 5.86521872 -3.83801546]
# Class Probabilities:  [3.29106283e-09 4.10160552e-12 1.72275139e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.27975169 -5.40685681]
# Class Probabilities:  [6.99379725e-03 7.16663693e-10 1.57890324e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [10.44252378  5.04836557]
# Class Probabilities:  [5.80296365e-12 1.81675159e-16 1.21972245e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.10454519 -8.59923558]
# Class Probabilities:  [5.95092576e-03 2.12255179e-15 3.44317363e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.79291315 9.94727029]
# Class Probabilities:  [6.73888503e-15 9.23207481e-03 3.07018305e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 6.54304649 -2.92516109]
# Class Probabilities:  [1.80482677e-09 2.05098772e-12 2.85022713e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.39028133 12.45758209]
# Class Probabilities:  [1.94378578e-20 6.86481420e-03 9.43473318e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [9.43284293 1.63188371]
# Class Probabilities:  [4.32924481e-11 3.32271874e-15 1.75666355e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [1.09569772 1.68119391]
# Class Probabilities:  [6.32639912e-05 1.04571550e-04 4.94483909e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.85994525 -1.67404675]
# Class Probabilities:  [1.68790895e-10 8.90475179e-14 3.49734450e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.72753408  1.0240291 ]
# Class Probabilities:  [2.67887443e-13 1.69757367e-18 7.80539779e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.36857973 2.77908536]
# Class Probabilities:  [9.80482979e-06 7.97357025e-05 8.12707001e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.46358952 -4.88042874]
# Class Probabilities:  [1.50199822e-14 3.23030385e-17 3.79292003e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-8.6591206 -3.386283 ]
# Class Probabilities:  [4.72956545e-05 9.52451337e-16 1.48233028e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.4916236  0.68401163]
# Class Probabilities:  [3.73622200e-10 1.14020335e-13 3.45332945e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-10.09417452 -10.83373126]
# Class Probabilities:  [1.16854373e-03 1.33621676e-26 7.57845224e-17]
# Predicted class is : 1
# ...
# For test point: [10.36682284 -2.94025912]
# Class Probabilities:  [5.66046664e-16 7.21097363e-20 4.52003120e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.17686513 -0.67617114]
# Class Probabilities:  [7.59216277e-12 8.79532300e-16 2.36766012e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.56032018 10.89248968]
# Class Probabilities:  [2.30863116e-15 1.06205269e-03 2.33158315e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [0.8138255 6.3426885]
# Class Probabilities:  [3.02666293e-09 4.43510903e-03 8.83213542e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.58026808  9.29140022]
# Class Probabilities:  [7.17637888e-16 1.08757558e-02 5.13392525e-09]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 8.85860141 -1.00596681]
# Class Probabilities:  [1.44485162e-11 2.63239151e-15 2.66877907e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 2.81652326 -2.73427081]
# Class Probabilities:  [3.33901319e-05 3.45349219e-08 1.45745787e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.91081684 -2.76984203]
# Class Probabilities:  [3.71535048e-03 3.00696841e-07 5.38800329e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-4.06815545  9.53292586]
# Class Probabilities:  [1.40742739e-19 5.74702013e-04 4.77086147e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [7.34079799 3.06978894]
# Class Probabilities:  [1.48914474e-08 1.51934668e-10 2.26077139e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.64032058 12.0068455 ]
# Class Probabilities:  [6.50538662e-22 7.83804933e-03 1.78927391e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.02141864 -0.12519999]
# Class Probabilities:  [1.47626634e-14 8.67245299e-20 6.31474414e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [2.83660161 7.63741536]
# Class Probabilities:  [3.10701247e-10 6.27669025e-04 8.38597262e-06]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 0.55253392 -2.86889414]
# Class Probabilities:  [1.00709495e-03 2.50464822e-07 2.52437961e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 3.97166844 -3.22481456]
# Class Probabilities:  [1.73176028e-06 1.76718575e-09 1.88440272e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.98490968 -4.84749576]
# Class Probabilities:  [1.21777176e-02 9.10913077e-10 8.69879564e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.10588756 1.58507517]
# Class Probabilities:  [1.15411705e-10 1.61135047e-14 2.14732511e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.99945013 -3.95313184]
# Class Probabilities:  [3.91564897e-08 4.12299969e-11 1.51410555e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.71883232 15.1537229 ]
# Class Probabilities:  [2.21738506e-25 4.47917222e-04 3.44261345e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.33163346  9.72288532]
# Class Probabilities:  [1.88565095e-15 1.45484810e-02 1.27911704e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [11.04296746  1.25113376]
# Class Probabilities:  [1.08815620e-13 3.43146910e-19 5.70643348e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.22009129  9.65386874]
# Class Probabilities:  [3.24349808e-15 1.43269336e-02 1.67076043e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.70876068  2.17594789]
# Class Probabilities:  [1.21986890e-05 1.82075272e-04 1.53201430e-05]
# Predicted class is : 2
# ******************************************************************************
# For test point: [4.51045177 7.56673947]
# Class Probabilities:  [5.92316752e-10 1.68156847e-05 2.16243130e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-1.29825485 13.66342044]
# Class Probabilities:  [1.36140275e-25 4.62363403e-03 5.15495774e-13]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-9.72864588 -6.0121161 ]
# Class Probabilities:  [3.42108837e-04 2.57849104e-20 1.40733374e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-0.48899942 17.98748437]
# Class Probabilities:  [7.50745205e-37 1.40802683e-04 3.93903917e-18]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-0.77337683  7.24172304]
# Class Probabilities:  [1.82846788e-11 9.37785105e-03 4.27117803e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-2.05007773 15.12157932]
# Class Probabilities:  [7.26911017e-31 1.26493270e-03 2.96690669e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-3.79351842 -4.31693215]
# Class Probabilities:  [1.33742172e-02 6.75972055e-10 3.36839037e-07]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.23987052 0.84895898]
# Class Probabilities:  [1.42366516e-08 2.72509391e-11 5.11210436e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-7.30596448 -3.23156572]
# Class Probabilities:  [3.61196538e-04 3.02776725e-13 4.61775535e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.28227684 -5.29628215]
# Class Probabilities:  [1.48842155e-02 3.07362473e-12 1.02867655e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.84284999 -4.65776943]
# Class Probabilities:  [3.81581117e-13 7.05247261e-16 6.09101438e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.36231452 14.65339584]
# Class Probabilities:  [4.71392556e-30 1.35765440e-03 6.67706773e-15]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-5.11518005 -5.99608685]
# Class Probabilities:  [1.74825754e-02 1.04641845e-12 7.63346297e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [8.61237327 4.48009751]
# Class Probabilities:  [6.02795071e-10 1.64830649e-12 5.77005850e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 0.95457177 -2.6426557 ]
# Class Probabilities:  [6.53670604e-04 3.01023513e-07 4.02418832e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.91149048 -9.43001297]
# Class Probabilities:  [4.24091923e-03 2.40800386e-17 1.99133362e-11]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.90520993  5.66899844]
# Class Probabilities:  [3.90070277e-14 1.99334819e-06 3.91989758e-10]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82381941  9.48699204]
# Class Probabilities:  [1.24023261e-20 1.23586804e-04 1.14999639e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [ 3.51481518 -2.69629369]
# Class Probabilities:  [8.36884254e-06 1.08783004e-08 2.07378150e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 4.81850398 -1.42510573]
# Class Probabilities:  [1.27780317e-06 4.01669659e-09 4.78753961e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.32369809 -7.1393455 ]
# Class Probabilities:  [5.70650345e-03 3.55394293e-12 5.35917759e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.46861438 -1.4433357 ]
# Class Probabilities:  [2.41400266e-04 2.40818642e-09 4.40989858e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-1.98740359 -5.57716425]
# Class Probabilities:  [5.01197373e-03 6.79102220e-10 2.04411088e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [11.65009927  4.93480248]
# Class Probabilities:  [1.74050431e-13 1.32351191e-19 4.77389845e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-5.29799896 -4.9997967 ]
# Class Probabilities:  [1.32065975e-02 5.49526388e-12 1.26484597e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-8.39210413 -8.94948394]
# Class Probabilities:  [5.65184052e-03 9.13826519e-21 1.46621177e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.03147831 -1.78716335]
# Class Probabilities:  [1.56839013e-03 1.68620585e-06 2.18048978e-04]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 7.24658383 -0.90643208]
# Class Probabilities:  [3.34587020e-09 3.08894214e-12 5.04991213e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 3.56004924 -1.02757626]
# Class Probabilities:  [1.98925261e-05 1.27560688e-07 3.48767060e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 7.36264317 -0.22355351]
# Class Probabilities:  [4.76399456e-09 4.75501315e-12 5.27385918e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-3.87468243  1.68851414]
# Class Probabilities:  [3.05689119e-06 6.69081629e-06 5.86536653e-07]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-1.71271544 -9.47990792]
# Class Probabilities:  [2.33189849e-05 8.15046412e-14 2.01538907e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-6.79673036 -6.33979581]
# Class Probabilities:  [1.11093468e-02 2.94809076e-15 1.61473613e-10]
# Predicted class is : 1
# ******************************************************************************
# For test point: [0.06008745 9.97311029]
# Class Probabilities:  [1.43331674e-15 1.33326031e-02 1.28649858e-08]
# Predicted class is : 2
# ******************************************************************************
# For test point: [-4.82746067 -3.56345126]
# Class Probabilities:  [6.54187082e-03 3.12321841e-10 8.01636868e-08]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-7.90632459 -9.21895769]
# Class Probabilities:  [6.21387797e-03 3.43114941e-20 3.23526973e-13]
# Predicted class is : 1
# ******************************************************************************
# For test point: [7.36874346 0.62545597]
# Class Probabilities:  [8.95084740e-09 1.27729000e-11 5.11348399e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 8.22552188 -0.20662172]
# Class Probabilities:  [3.55276884e-10 1.32005885e-13 3.97357417e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 1.20850538 -2.82403166]
# Class Probabilities:  [4.45033110e-04 1.87472420e-07 4.62617045e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [3.21579751 2.94840046]
# Class Probabilities:  [4.92574886e-06 2.33291004e-05 1.23768489e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.20729307 -5.44771275]
# Class Probabilities:  [6.48176869e-03 7.12282677e-10 1.68874378e-06]
# Predicted class is : 1
# ******************************************************************************
# For test point: [-5.40036386 -5.32174925]
# Class Probabilities:  [1.44906227e-02 2.11649099e-12 7.96126326e-09]
# Predicted class is : 1
# ******************************************************************************
# For test point: [ 0.15531485 -4.12155615]
# Class Probabilities:  [1.01785110e-03 2.94580889e-08 8.44374293e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.22382129 5.71360307]
# Class Probabilities:  [7.86496521e-11 1.59105050e-13 1.39962771e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-0.63952042 -4.65786291]
# Class Probabilities:  [2.03244296e-03 1.01082229e-08 2.43494535e-05]
# Predicted class is : 1
# ******************************************************************************
# For test point: [9.15705042 1.29990602]
# Class Probabilities:  [7.95674901e-11 9.43749549e-15 2.23672031e-03]
# Predicted class is : 3
# ******************************************************************************
# For test point: [10.95944226  1.34437573]
# Class Probabilities:  [1.67574463e-13 6.14107643e-19 6.03757615e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [12.70138697  4.8417071 ]
# Class Probabilities:  [5.15742820e-15 1.33332353e-22 1.68605350e-05]
# Predicted class is : 3
# ******************************************************************************
# For test point: [8.13412403 8.8823782 ]
# Class Probabilities:  [4.67545228e-12 5.33499378e-11 3.31316242e-06]
# Predicted class is : 3
# ******************************************************************************
# For test point: [-2.02416693 11.64233379]
# Class Probabilities:  [1.43515633e-21 6.75181474e-03 2.25681692e-11]
# Predicted class is : 2
# ******************************************************************************
# For test point: [1.06908312 1.27293507]
# Class Probabilities:  [1.03682341e-04 6.78552626e-05 5.54511720e-04]
# Predicted class is : 3
# ******************************************************************************
# For test point: [ 9.66236602 -2.51130178]
# Class Probabilities:  [3.55271530e-14 5.84999544e-18 9.69454730e-04]
# Predicted class is : 3
# ******************************************************************************

# %%
# TODO [8]: Compute the accuracy of the generated Bayesian classifier
# WITHOUT USING ANY FOR LOOPs.
accuracy = np.mean(predicted_classes==test_data_true['Class'])
print('Accuracy = ' + str(round(accuracy,4) * 100) + '%')
# Out:
# Accuracy = 95.56%

# %%
# TODO [9]: Generate a 3D-plot for the generated distributions. x-axis and y-axis represent the features of the data,
#           where z-axis represent the Gaussian probability N at this point.
numClasses=3
x = np.linspace(-10, 10, 300)
y = np.linspace(-10, 15, 300)
X, Y = np.meshgrid(x, y)
Z = np.zeros(X.shape)
for i in range(Z.shape[0]):
    for j in range(Z.shape[1]):
       x_test=x_test = np.array([X[i,j],Y[i,j]])
       classProbabilities = np.zeros(numClasses)
       for k in range(0,numClasses):
         classProbabilities[k]=multivariate_normal_gaussian(x_test,estimate_means[k],estimate_covariances[k])[0][0]*pClasses[k]
       Z[i, j] =np.sum(classProbabilities)

# Make a 3D plot, do not change code
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(X, Y, Z, cmap='viridis', linewidth=0)
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()

# %%
# How can you judge your plot is correct?
'''
    Your Answer:
    mean at(0,0)
    symmetric
'''
# Out:
# '\n    Your Answer:\n    mean at(0,0)\n    symmetric\n'
